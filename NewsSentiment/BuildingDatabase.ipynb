# %% [markdown]
# # News Sentiment Database
# <br>
# There was a kaggle competition (https://www.kaggle.com/c/two-sigma-financial-news) by Two Sigma a few months ago, looking to identify any potential correlation between news event and stock performance. In the competition, news and stock market data were provided. The source of data are from Thomson Reuters and Intrino (which is part of Thomson Reuters as well). One of the key feature in the news data is sentiment score (and confidence of the score). Unfortunately, there was no clarification/details on the sentiment scoring model. A sentiment score (can sometimes be refer as polarity score) refers to having negative, postive or neutral expression.
#
# ![Data is King](https://www.denofprogramming.com/wp-content/uploads/2015/07/KingData-300x236.jpg)
#
# Therefore, the notebook is to explore and understand how sentiment scoring works, then curate local news, score news event with the goal to train a ML model for local news sentiment scoring

# %% [markdown]
# ## Strategy
# The "Hello World" of Sentiment Analysis begins with "Classifying IMDB movie reviews". The following is a good starting point using vectorization techniques (bag-of-words) with machine learning model (https://towardsdatascience.com/sentiment-analysis-with-python-part-1-5ce197074184). The general strategy for bag-of-words is to : <br>
# <br>
# 1. Remove any non-essential characters (commas, semicolons, angled brackets, etc) - removing punctuation, HTML tags, forced lower case<br>
#     a. removing stop words - words that do not carry weights (i.e. they, we, if, I, you, etc)<br>
#     b. stemming and lemmatization<br>
#         i. stemming - cut off words to root words (brute force) <br>
#         ii. lemmatization - complex transformation to root words <br>
# 2. Vectorize/Tokenize every word in all comments (document database is also known as corpus) <br>
#     a. vectorize combination of word (n-gram technique) <br>
#     b. vectorize words importance and words count with inverse relationship (TF-IDF) (i.e. words that appear many times have lower importance than words that appear once or twice) <br>
# 3. Match X (vector) and Y (score) and use sklearn library to train a model <br>
#     a. the produced vector are typically sparse in nature - lots of zeros (i.e. some words are not found in other comments). Common model is to use SVM with linear kernel for separation. <br>
#     b. optional : use a neural network to classify sentiment.

# %% [markdown]
# As a starter, we will collect some news from a local site.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

url = "http://www.thestar.com.my/business"
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')
#print(soup.prettify())

for tag_object in soup.find_all('a'):
    print(tag_object.get_attribute_list("data-content-title"))
# Out:
# ['The Star Online']
# ['ePaper']
# ['Log In']
# [None]
# ['https://login.thestar.com.my/accountinfo/profile.aspx']
# ['https://login.thestar.com.my/accountinfo/changepassword.aspx']
# ['https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx']
# ['https://login.thestar.com.my/accountinfo/billing.aspx']
# ['https://login.thestar.com.my/accountinfo/transhistory.aspx']
# ['http://www.thestar.com.my/foryou/edit']
# ['http://www.thestar.com.my/saved-articles']
# ['https://www.thestar.com.my/faqs/']
# ['https://www.thestar.com.my']
# ['The Star Online']
# ['Home']
# ['For You']
# ['News']
# ['Latest']
# ['Nation']
# ['Asean+']
# ['World']
# ['Environment']
# ['In Other Media']
# ['True or Not']
# ['Focus']
# ['Business']
# ['News']
# ['StarBiz Premium']
# ['SMEBiz']
# ['Market Watch']
# ['Bursa Overview']
# ['Market Movers']
# ['Financial Results']
# ['Dividends']
# ['Bonus']
# ['IPO']
# ['Unit Trust']
# ['Exchange Rates']
# ['My Portfolio']
# ['Sport']
# ['Football']
# ['Golf']
# ['Badminton']
# ['Tennis']
# ['Motorsport']
# ['Community Sports']
# ['Other Sports']
# ['Say What']
# ['Metro']
# ['Metro News']
# ['Views']
# ['Lifestyle']
# ['Entertainment &amp; Style']
# ['People &amp; Living']
# ['Health &amp; Family']
# ['Travel &amp; Culture']
# ['Food']
# ['Food News']
# ['Eating Out']
# ['Kuali']
# ['Tech']
# ['Education']
# ['News']
# ['Courses']
# ['Opinion']
# ['Columnists']
# ['Letters']
# ['Videos']
# ['More']
# ['Photos']
# ['Classifieds']
# ['Events']
# ['StarCherish.com']
# ['Search']
# ['Close Search']
# [None]
# ['https://login.thestar.com.my/accountinfo/profile.aspx']
# ['https://login.thestar.com.my/accountinfo/changepassword.aspx']
# ['https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx']
# ['https://login.thestar.com.my/accountinfo/billing.aspx']
# ['https://login.thestar.com.my/accountinfo/transhistory.aspx']
# ['http://www.thestar.com.my/foryou/edit']
# ['http://www.thestar.com.my/saved-articles']
# ['https://www.thestar.com.my/faqs/']
# ['https://www.thestar.com.my']
# ['Log In']
# ['Advance Search']
# ['Advance Search']
# ['Home']
# ['For You']
# ['News']
# ['Latest']
# ['Nation']
# ['Asean+']
# ['World']
# ['Environment']
# ['In Other Media']
# ['True or Not']
# ['Focus']
# ['Business']
# ['News']
# ['StarBiz Premium']
# ['SMEBiz']
# ['Unit Trust']
# ['Exchange Rates']
# ['My Portfolio']
# ['Market Watch']
# ['Bursa Overview']
# ['Market Movers']
# ['Financial Results']
# ['Dividends']
# ['Bonus']
# ['IPO']
# ['Sport']
# ['Football']
# ['Golf']
# ['Badminton']
# ['Tennis']
# ['Motorsport']
# ['Community Sports']
# ['Other Sport']
# ['Say What']
# ['Metro']
# ['Metro News']
# ['Views']
# ['Lifestyle']
# ['Entertainment &amp; Style']
# ['People &amp; Living']
# ['Health &amp; Family']
# ['Travel &amp; Culture']
# ['Food']
# ['Food News']
# ['Eating Out']
# ['Kuali']
# ['Tech']
# ['Education']
# ['News']
# ['Courses']
# ['Opinion']
# ['Columnists']
# ['Letters']
# ['Videos']
# ['More']
# ['Photos']
# ['StarCherish.com']
# ['Classifieds']
# ['Events']
# [None]
# [None]
# [None]
# [None]
# ['Page 2']
# [None]
# [None]
# [None]
# [None]
# ['Home']
# ['News']
# ['Business']
# ['Sport']
# ['Metro']
# ['Lifestyle']
# ['Food']
# ['Tech']
# ['Education']
# ['Opinion']
# ['The Star newspaper']
# ['StarBiz Premium']
# ['Other Publications']
# ['ePaper']
# ['SMS Services']
# ['View Our Rate Card']
# ['About Us']
# ['Job Opportunities']
# ['Investor Relations']
# ['Contact Us']
# ['FAQs']
# ['Privacy Statement']
# ['Terms &amp; Conditions']
# ['myStarjob.com']
# ['Carsifu']
# ['StarProperty']
# ['iBilik']
# ['R.AGE']
# ['mStar']
# ['Kuali']
# ['TheStarTV.com']
# ['StarCherish.com']
# ['Kuntum']
# ['Facebook']
# ['Twitter']
# ['Contact Us']
# ['App Store']
# ['Google Play']
# ['APPGALLERY']
# ['Asia News Network']
# ['Suria FM']
# ['988']
# ['dimsum']
# ['App Store']
# ['Google Play']
# ['APPGALLERY']
# ['Home']
# ['News']
# ['Business']
# ['Sport']
# ['Metro']
# ['Lifestyle']
# ['Food']
# ['Tech']
# ['Education']
# ['Opinion']
# ['The Star newspaper']
# ['StarBiz Premium']
# ['Other Publications']
# ['ePaper']
# ['SMS Services']
# ['About Us']
# ['Job Opportunities']
# ['Investor Relations']
# ['Contact Us']
# ['FAQs']
# ['View Our Rate card']
# ['Privacy Statement']
# ['Terms &amp; Conditions']
# ['Star2.com']
# ['myStarjob.com']
# ['Carsifu']
# ['StarProperty']
# ['Propwall']
# ['iBilik']
# ['R.AGE']
# ['mStar']
# ['Kuali']
# ['TheStarTV.com']
# ['StarCherish.com']
# ['Kuntum']
# ['dimsum']
# ['Suria']
# ['988']
# ['Facebook']
# ['Twitter']
# [None]
# [None]
# [None]

# %% [markdown]
# Unfortunately, the website uses javascript to display HTML object and requests does not have framework to understand javascript. Selenium is a better tool for this purpose.
#
# ## Combination of Selenium and BeautifulSoup
# 1. Selenium's webdriver to scrape mainpage for link
# 2. Scour each link with request and bs4
# 3. extract day, date, author, title, content

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("disabled-infobars")
options.add_argument("--incognito")

url = "http://www.thestar.com.my/business"
browser = webdriver.Chrome(chrome_options = options)
browser.get(url)
#tag_element = browser.find_elements_by_xpath('//*[@id="form1"]')
items = browser.find_elements_by_xpath('//h2/a[@href]')
# Out:
# c:\users\mcheong\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: use options instead of chrome_options
#   if __name__ == '__main__':

# %%
import pandas as pd
DF_list = []

for item in items:
    DF_list.append([item.get_attribute('data-content-title'), item.get_attribute('data-content-author'), item.get_attribute('href')])

browser.close()

DF = pd.DataFrame(DF_list, columns = ["Title", "Author", "Link"])
DF = DF.applymap(str)
DF = DF[DF["Title"] != "None"]
DF
# Out:
#                                                 Title        Author  \
# 0              Tough job lies in wait for new Cabinet            NA
# 1     Bursa stages mild rebound, PChem and banks lift   Joseph Chin
# 2   Quick take: Magni-Tech’s falls after earnings ...            NA
# 3    Quick take: Uzma shares rise 9% on contract news            NA
# 4   Price war could spark new downcycle for oil, d...            NA
# 5   Trading ides: Leong Hup, Uzma, Kim Teck Cheong...            NA
# 6           Direct hit seen for oil and gas companies            NA
# 7             Markets in turmoil as oil price crashes            NA
# 8                          Zafrul quits CIMB CEO post            NA
# 9   Ringgit weakens against US$ on Covid-19, plung...            NA
# 14  Tengku Zafrul's appointment as Finance Ministe...            NA
# 15  Oil prices rise 4% after biggest one-day fall ...            NA
# 16  CGS-CIMB Research sees oil-related revenue fal...            NA
# 17                    CEO shares a recipe for success            NA
# 18     Asia shares slip, stimulus talk offers support            NA
# 19  Semicon equipment makers see 3% growth to US$5...            NA
# 20  Asia shares try to find a floor after headlong...            NA
# 21       US stocks plunge most since financial crisis            NA
# 22  Bursa Malaysia index-linked stocks tumble on f...            NA
# 23  Tesco sells Thai and M’sian businesses to CP G...  By ROYCE TAN
# 24            Hassan Marican steps down from Khazanah            NA
# 25                          Bina secures RM210mil job            NA
# 26            Banks to see flatter earnings this year  By ROYCE TAN
# 27  Daibochi posts record Q2 net profit of RM14.63mil            NA
# 28    Petronas appoints KTC as main Mesra distributor            NA
# 29                 Gold wavers after topping US$1,700            NA
# 30            Leong Hup diversifies into aquatic feed            NA
# 31  Names of victims read aloud at murder trial ov...            NA
# 32                    CEO shares a recipe for success            NA
#
#                                                  Link
# 0   https://www.thestar.com.my/business/business-n...
# 1   https://www.thestar.com.my/business/business-n...
# 2   https://www.thestar.com.my/business/business-n...
# 3   https://www.thestar.com.my/business/business-n...
# 4   https://www.thestar.com.my/business/business-n...
# 5   https://www.thestar.com.my/business/business-n...
# 6   https://www.thestar.com.my/business/business-n...
# 7   https://www.thestar.com.my/business/business-n...
# 8   https://www.thestar.com.my/business/business-n...
# 9   https://www.thestar.com.my/business/business-n...
# 14          https://www.thestartv.com/v/5e662ea07cf1c
# 15  https://www.thestar.com.my/business/business-n...
# 16  https://www.thestar.com.my/business/business-n...
# 17  https://www.thestar.com.my/news/education/2020...
# 18  https://www.thestar.com.my/business/business-n...
# 19  https://www.thestar.com.my/business/business-n...
# 20  https://www.thestar.com.my/business/business-n...
# 21  https://www.thestar.com.my/business/business-n...
# 22  https://www.thestar.com.my/business/business-n...
# 23  https://www.thestar.com.my/business/business-n...
# 24  https://www.thestar.com.my/business/business-n...
# 25  https://www.thestar.com.my/business/business-n...
# 26  https://www.thestar.com.my/business/business-n...
# 27  https://www.thestar.com.my/business/business-n...
# 28  https://www.thestar.com.my/business/business-n...
# 29  https://www.thestar.com.my/business/business-n...
# 30  https://www.thestar.com.my/business/business-n...
# 31  https://www.thestar.com.my/business/business-n...
# 32  https://www.thestar.com.my/news/education/2020...

# %% [markdown]
# ## Function Declaration for
# ##### 1. Displaying html page with tag p
# ##### 2. Scrape individual link and return as list
# ##### 3. Scan all tag p, combine list into single DF

# %%
import requests
from bs4 import BeautifulSoup
import time

def showSoupP(link):
    print("Scraping Link",link)
    response = requests.get(link)
    soup = BeautifulSoup(response.content,'html.parser')
    element_list = soup.find_all("p")
    for i in element_list:
        print(i.get_text())

def scrapeLink(link):
    print("Scraping Link",link)
    response = requests.get(link)
    soup = BeautifulSoup(response.content,'html.parser')
    element_list = soup.find_all("p")
    if element_list != []:
        text_list = []
        for element in element_list:
            text_list.append(element.get_text())
        try:
            trimmingIndex = text_list.index("We're sorry, this article is unavailable at the moment. If you wish to read this article, kindly contact our Customer Service team at 1-300-88-7827. Thank you for your patience - we're bringing you a new and improved experience soon!")
        except:
            try:
                trimmingIndex = text_list.index(" ")
            except:
                return [link,"NA","NA","NA","NA"]
        day = text_list[0].replace("\n","").strip().split(",")[0]
        date = text_list[0].replace("\n","").strip().split(",")[1].strip()
        if ("by" in text_list[1].lower()) and (len(text_list[1]) < 50 ):
            author = text_list[1].lower().strip("by").strip()
            content = ''.join(text_list[2:trimmingIndex])
        else:
            author = "NA"
            content = ''.join(text_list[1:trimmingIndex])
    else:
        return [link,"NA","NA","NA","NA"]
    
    return [link,day,date,author,content]
 
def scrapeIndividualPage(args):
    contentDFList = []

    if (isinstance(args,pd.DataFrame)):
        for i in args["Link"]:
            result = scrapeLink(i)
            contentDFList.append(result)
            time.sleep(2)
    else:
        result = scrapeLink(args)
        contentDFList.append(result)
    
    DF = pd.DataFrame(contentDFList, columns = ["Link","Day","Date","_Author","Content"])
    return DF

# %%
singleDF = scrapeIndividualPage("https://www.thestar.com.my/business/business-news/2020/03/10/markets-in-turmoil-as-oil-price-crashes")
singleDF
# Out:
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/10/markets-in-turmoil-as-oil-price-crashes
#                                                 Link      Day         Date  \
# 0  https://www.thestar.com.my/business/business-n...  Tuesday  10 Mar 2020
#
#        _Author                                            Content
# 0  daniel khoo  Oil prices tanked by more than 30%, sending th...

# %% [markdown]
# ## Final Output

# %%
#contentDF = scrapeIndividualPage(DF)
mergedDF = DF.merge(contentDF, left_on="Link", right_on="Link")
mergedDF["Author"].update(mergedDF.pop("_Author"))
mergedDF = mergedDF.drop(columns=["Link"])
mergedDF
# Out:
#                                                 Title  \
# 0              Tough job lies in wait for new Cabinet
# 1     Bursa stages mild rebound, PChem and banks lift
# 2   Quick take: Magni-Tech’s falls after earnings ...
# 3    Quick take: Uzma shares rise 9% on contract news
# 4   Price war could spark new downcycle for oil, d...
# 5   Trading ides: Leong Hup, Uzma, Kim Teck Cheong...
# 6           Direct hit seen for oil and gas companies
# 7             Markets in turmoil as oil price crashes
# 8                          Zafrul quits CIMB CEO post
# 9   Ringgit weakens against US$ on Covid-19, plung...
# 10  Tengku Zafrul's appointment as Finance Ministe...
# 11  Oil prices rise 4% after biggest one-day fall ...
# 12  CGS-CIMB Research sees oil-related revenue fal...
# 13                    CEO shares a recipe for success
# 14     Asia shares slip, stimulus talk offers support
# 15  Semicon equipment makers see 3% growth to US$5...
# 16  Asia shares try to find a floor after headlong...
# 17       US stocks plunge most since financial crisis
# 18  Bursa Malaysia index-linked stocks tumble on f...
# 19  Tesco sells Thai and M’sian businesses to CP G...
# 20            Hassan Marican steps down from Khazanah
# 21                          Bina secures RM210mil job
# 22            Banks to see flatter earnings this year
# 23  Daibochi posts record Q2 net profit of RM14.63mil
# 24    Petronas appoints KTC as main Mesra distributor
# 25                 Gold wavers after topping US$1,700
# 26            Leong Hup diversifies into aquatic feed
# 27  Names of victims read aloud at murder trial ov...
# 28                    CEO shares a recipe for success
#
#                                                Author      Day         Date  \
# 0                                          tee lin sa  Tuesday  10 Mar 2020
# 1                                         joseph chin  Tuesday  10 Mar 2020
# 2                                                  NA  Tuesday  10 Mar 2020
# 3                                                  NA  Tuesday  10 Mar 2020
# 4                                                  NA  Tuesday  10 Mar 2020
# 5                                                  NA  Tuesday  10 Mar 2020
# 6                                                  NA  Tuesday  10 Mar 2020
# 7                                         daniel khoo  Tuesday  10 Mar 2020
# 8   commenting on his new appointment, tengku zafr...  Tuesday  10 Mar 2020
# 9                                                  NA  Tuesday  10 Mar 2020
# 10                                                 NA       NA           NA
# 11                                                 NA  Tuesday  10 Mar 2020
# 12                                                 NA  Tuesday  10 Mar 2020
# 13                                                 NA       NA           NA
# 14  sydney: asian markets skidded again on tuesday...  Tuesday  10 Mar 2020
# 15                                                 NA  Tuesday  10 Mar 2020
# 16                                                 NA  Tuesday  10 Mar 2020
# 17                                                 NA  Tuesday  10 Mar 2020
# 18  the oil price plunge also saw petronas chemica...  Tuesday  10 Mar 2020
# 19                                          royce tan  Tuesday  10 Mar 2020
# 20                                                 NA  Tuesday  10 Mar 2020
# 21                                                 NA  Tuesday  10 Mar 2020
# 22                                          royce tan  Tuesday  10 Mar 2020
# 23                                                 NA  Tuesday  10 Mar 2020
# 24  ktc said mesra outlets would also benefit from...  Tuesday  10 Mar 2020
# 25                                                 NA  Tuesday  10 Mar 2020
# 26  lhi said it plans to enhance the asset’s capac...  Tuesday  10 Mar 2020
# 27                                                 NA  Tuesday  10 Mar 2020
# 28                                                 NA       NA           NA
#
#                                               Content
# 0   The new Cabinet has a tall order ahead of them...
# 1   At Bursa on Monday, foreign funds stepped up t...
# 2   KUALA LUMPUR: Shares in Magni-Tech Industries ...
# 3   KUALA LUMPUR: UZMA BHD shares advanced almost ...
# 4
# 5   KUALA LUMPUR: Leong Hup International Bhd, UZM...
# 6   UOB Kay Hian said that the combination of Covi...
# 7   Oil prices tanked by more than 30%, sending th...
# 8   PETALING JAYA: CIMB GROUP HOLDINGS BHD group c...
# 9   KUALA LUMPUR: The ringgit remained weaker agai...
# 10                                                 NA
# 11  Oil double donkeySINGAPORE: Oil prices rose by...
# 12  “Hence, we estimate that the government would ...
# 13                                                 NA
# 14  Speculation of more central bank rate cuts and...
# 15  KUALA LUMPUR: Global fabrication equipment spe...
# 16  "The collapse in oil prices and associated cre...
# 17  The S&P 500 sank the most since December 2008,...
# 18  PETALING JAYA: Index-linked stocks tumbled to ...
# 19  Checking out: Tesco’s latest store in Tanjung ...
# 20  Khazanah said Hassan had stepped down to pursu...
# 21  Bina said its wholly owned subsidiary BDB Infr...
# 22  Given the dovish sentiment by the central bank...
# 23  Daibochi executive director Low Jin Wei(pic) s...
# 24  PETALING JAYA: Petroliam Nasional Bhd (Petrona...
# 25  Safe haven: An employee arranges one kilogramm...
# 26  PETALING JAYA: Leong Hup International Bhd (LH...
# 27  Judges take place during the criminal trial ag...
# 28                                                 NA

# %% [markdown]
# So far this is a good start. There are a few place for improvements (i.e. scraping cleaner content text, dropping missing content, cleaner author naming convention). Lets combine each component into a python class that could be executed daily and collect more data points. We will then combine the 5-days output to a larger DF for ranking. Let's start with some cool NLP work !
#
# ## NLP (Part-2)
