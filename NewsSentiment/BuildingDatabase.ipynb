# %% [markdown]
# # News Database
# <br>
# There was a kaggle competition (https://www.kaggle.com/c/two-sigma-financial-news) by Two Sigma a few months ago, looking to identify any potential correlation between news event and stock performance. In the competition, news and stock market data were provided. The source of data are from Thomson Reuters and Intrino (which is part of Thomson Reuters as well). One of the key feature in the news data is sentiment score (and confidence of the score). Unfortunately, there was no clarification/details on the sentiment scoring model. A sentiment score (can sometimes be refer as polarity score) refers to having negative, postive or neutral expression.
#
# ![Data is King](https://www.denofprogramming.com/wp-content/uploads/2015/07/KingData-300x236.jpg)
#
# Therefore, the notebook is to explore and understand how sentiment scoring works, then curate local news, score news event with the goal to train a ML model for local news sentiment scoring

# %% [markdown]
# ## Strategy
# The "Hello World" of Sentiment Analysis begins with "Classifying IMDB movie reviews". The following is a good starting point using vectorization techniques (bag-of-words) with machine learning model (https://towardsdatascience.com/sentiment-analysis-with-python-part-1-5ce197074184). The general strategy for bag-of-words is to : <br>
# <br>
# 1. Remove any non-essential characters (commas, semicolons, angled brackets, etc) - removing punctuation, HTML tags, forced lower case<br>
#     a. removing stop words - words that do not carry weights (i.e. they, we, if, I, you, etc)<br>
#     b. stemming and lemmatization<br>
#         i. stemming - cut off words to root words (brute force) <br>
#         ii. lemmatization - complex transformation to root words <br>
# 2. Vectorize/Tokenize every word in all comments (document database is also known as corpus) <br>
#     a. vectorize combination of word (n-gram technique) <br>
#     b. vectorize words importance and words count with inverse relationship (TF-IDF) (i.e. words that appear many times have lower importance than words that appear once or twice) <br>
# 3. Match X (vector) and Y (score) and use sklearn library to train a model <br>
#     a. the produced vector are typically sparse in nature - lots of zeros (i.e. some words are not found in other comments). Common model is to use SVM with linear kernel for separation. <br>
#     b. optional : use a neural network to classify sentiment.

# %% [markdown]
# As a starter, we will collect some news from a local site.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

url = "http://www.thestar.com.my/business"
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')
#print(soup.prettify())

for tag_object in soup.find_all('a'):
    print(tag_object.get_attribute_list("data-content-title"))
# Out:
# ['The Star Online']
# ['ePaper']
# ['Log In']
# [None]
# ['https://login.thestar.com.my/accountinfo/profile.aspx']
# ['https://login.thestar.com.my/accountinfo/changepassword.aspx']
# ['https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx']
# ['https://login.thestar.com.my/accountinfo/billing.aspx']
# ['https://login.thestar.com.my/accountinfo/transhistory.aspx']
# ['http://www.thestar.com.my/foryou/edit']
# ['http://www.thestar.com.my/saved-articles']
# ['https://www.thestar.com.my/faqs/']
# ['https://www.thestar.com.my']
# ['The Star Online']
# ['Home']
# ['For You']
# ['News']
# ['Latest']
# ['Nation']
# ['Asean+']
# ['World']
# ['Environment']
# ['In Other Media']
# ['True or Not']
# ['Focus']
# ['Business']
# ['News']
# ['StarBiz Premium']
# ['SMEBiz']
# ['Market Watch']
# ['Bursa Overview']
# ['Market Movers']
# ['Financial Results']
# ['Dividends']
# ['Bonus']
# ['IPO']
# ['Unit Trust']
# ['Exchange Rates']
# ['My Portfolio']
# ['Sport']
# ['Football']
# ['Golf']
# ['Badminton']
# ['Tennis']
# ['Motorsport']
# ['Community Sports']
# ['Other Sports']
# ['Say What']
# ['Metro']
# ['Metro News']
# ['Views']
# ['Lifestyle']
# ['Entertainment &amp; Style']
# ['People &amp; Living']
# ['Health &amp; Family']
# ['Travel &amp; Culture']
# ['Food']
# ['Food News']
# ['Eating Out']
# ['Kuali']
# ['Tech']
# ['Education']
# ['News']
# ['Courses']
# ['Opinion']
# ['Columnists']
# ['Letters']
# ['Videos']
# ['More']
# ['Photos']
# ['Classifieds']
# ['Events']
# ['StarCherish.com']
# ['Search']
# ['Close Search']
# [None]
# ['https://login.thestar.com.my/accountinfo/profile.aspx']
# ['https://login.thestar.com.my/accountinfo/changepassword.aspx']
# ['https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx']
# ['https://login.thestar.com.my/accountinfo/billing.aspx']
# ['https://login.thestar.com.my/accountinfo/transhistory.aspx']
# ['http://www.thestar.com.my/foryou/edit']
# ['http://www.thestar.com.my/saved-articles']
# ['https://www.thestar.com.my/faqs/']
# ['https://www.thestar.com.my']
# ['Log In']
# ['Advance Search']
# ['Advance Search']
# ['Home']
# ['For You']
# ['News']
# ['Latest']
# ['Nation']
# ['Asean+']
# ['World']
# ['Environment']
# ['In Other Media']
# ['True or Not']
# ['Focus']
# ['Business']
# ['News']
# ['StarBiz Premium']
# ['SMEBiz']
# ['Unit Trust']
# ['Exchange Rates']
# ['My Portfolio']
# ['Market Watch']
# ['Bursa Overview']
# ['Market Movers']
# ['Financial Results']
# ['Dividends']
# ['Bonus']
# ['IPO']
# ['Sport']
# ['Football']
# ['Golf']
# ['Badminton']
# ['Tennis']
# ['Motorsport']
# ['Community Sports']
# ['Other Sport']
# ['Say What']
# ['Metro']
# ['Metro News']
# ['Views']
# ['Lifestyle']
# ['Entertainment &amp; Style']
# ['People &amp; Living']
# ['Health &amp; Family']
# ['Travel &amp; Culture']
# ['Food']
# ['Food News']
# ['Eating Out']
# ['Kuali']
# ['Tech']
# ['Education']
# ['News']
# ['Courses']
# ['Opinion']
# ['Columnists']
# ['Letters']
# ['Videos']
# ['More']
# ['Photos']
# ['StarCherish.com']
# ['Classifieds']
# ['Events']
# [None]
# [None]
# [None]
# [None]
# ['Page 2']
# [None]
# [None]
# [None]
# [None]
# ['Home']
# ['News']
# ['Business']
# ['Sport']
# ['Metro']
# ['Lifestyle']
# ['Food']
# ['Tech']
# ['Education']
# ['Opinion']
# ['The Star newspaper']
# ['StarBiz Premium']
# ['Other Publications']
# ['ePaper']
# ['SMS Services']
# ['View Our Rate Card']
# ['About Us']
# ['Job Opportunities']
# ['Investor Relations']
# ['Contact Us']
# ['FAQs']
# ['Privacy Statement']
# ['Terms &amp; Conditions']
# ['myStarjob.com']
# ['Carsifu']
# ['StarProperty']
# ['iBilik']
# ['R.AGE']
# ['mStar']
# ['Kuali']
# ['TheStarTV.com']
# ['StarCherish.com']
# ['Kuntum']
# ['Facebook']
# ['Twitter']
# ['Contact Us']
# ['App Store']
# ['Google Play']
# ['APPGALLERY']
# ['Asia News Network']
# ['Suria FM']
# ['988']
# ['dimsum']
# ['App Store']
# ['Google Play']
# ['APPGALLERY']
# ['Home']
# ['News']
# ['Business']
# ['Sport']
# ['Metro']
# ['Lifestyle']
# ['Food']
# ['Tech']
# ['Education']
# ['Opinion']
# ['The Star newspaper']
# ['StarBiz Premium']
# ['Other Publications']
# ['ePaper']
# ['SMS Services']
# ['About Us']
# ['Job Opportunities']
# ['Investor Relations']
# ['Contact Us']
# ['FAQs']
# ['View Our Rate card']
# ['Privacy Statement']
# ['Terms &amp; Conditions']
# ['Star2.com']
# ['myStarjob.com']
# ['Carsifu']
# ['StarProperty']
# ['Propwall']
# ['iBilik']
# ['R.AGE']
# ['mStar']
# ['Kuali']
# ['TheStarTV.com']
# ['StarCherish.com']
# ['Kuntum']
# ['dimsum']
# ['Suria']
# ['988']
# ['Facebook']
# ['Twitter']

# %% [markdown]
# Unfortunately, the website uses javascript to display HTML object. Selenium is a better tool for this purpose.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("disabled-infobars")
options.add_argument("--incognito")

url = "http://www.thestar.com.my/business"
browser = webdriver.Chrome(chrome_options = options)
browser.get(url)
#tag_element = browser.find_elements_by_xpath('//*[@id="form1"]')
items = browser.find_elements_by_xpath('//h2/a[@href]')
browser.close()
# Out:
# c:\users\mcheong\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: use options instead of chrome_options
#   if __name__ == '__main__':

# %%
DF_list = []
for item in items:
    DF_list.append([item.get_attribute('data-content-title'), item.get_attribute('data-content-author'), item.get_attribute('href')])

# %%
import pandas as pd

DF = pd.DataFrame(DF_list, columns = ["Title", "Author", "Link"])

# %%
DF = DF.applymap(str)
DF = DF[DF["Title"] != "None"]
DF
# Out:
#                                                 Title  \
# 0                   Chips sector hard hit by Covid-19
# 1               Foreign selling extends to third week
# 2   Carnage in oil markets batter Bursa's oil and ...
# 3   Quick take: Oil and gas counters tumble after ...
# 4   Affin Hwang maintains 'netural' on telcos, Max...
# 5   Trading ideas: TRC Synergy, Acoustech, Vsolar,...
# 6   Saudi Arabia plans big oil output hike, beginn...
# 7         Vehicle sales expected to grow 9% this year
# 8   Datasonic MD says firm’s ability to secure gov...
# 9    Ringgit extends last week's loss against the US$
# 14                       An uphill task for Muhyiddin
# 15  CGS-CIMB Research sees Dialog, Lotte winning i...
# 16  Reconfigured area could boost rental income fo...
# 17                      Putin starts war on shale oil
# 18  Boeing’s New CEO regrets blasting predecessor ...
# 19  Zafrul: SMEs deserve all help during trying times
# 20                             Engineered for success
# 21   Virus forces Asia’s super rich to work from home
# 22  How artificial intelligence will change the co...
# 23                      Aramco slumps below IPO price
# 24                    Japan’s timber boost for Ta Ann
# 25  S P Setia set to achieve higher earnings this ...
# 26  Investors look for buys as virus fears crush t...
# 27  JPMorgan sees ‘early signs’ of stress on credi...
# 28   Central banks search for answers to virus impact
# 29    Globetronics plans RM30mil capex for first half
# 30         Sinotop set to enter govt e-services space
# 31        Need for global cooperation to save the day
# 32                             Engineered for success
#
#                                   Author  \
# 0                                     NA
# 1                         Leong Hung Yee
# 2                            Joseph Chin
# 3                                     NA
# 4                                     NA
# 5                                     NA
# 6                                     NA
# 7                                     NA
# 8                                     NA
# 9                                     NA
# 14                                    NA
# 15                                    NA
# 16                                    NA
# 17                                    NA
# 18                                    NA
# 19                                    NA
# 20                                    NA
# 21                                    NA
# 22  Comment - By Parameswaran Sivalingam
# 23                                    NA
# 24                             JACK WONG
# 25                  By EUGENE MAHALINGAM
# 26                                    NA
# 27                                    NA
# 28                                    NA
# 29                          By DAVID TAN
# 30                        By TEE LIN SAY
# 31     Plain Speaking - By Yap Leng Kuen
# 32                                    NA
#
#                                                  Link
# 0   https://www.thestar.com.my/business/business-n...
# 1   https://www.thestar.com.my/business/business-n...
# 2   https://www.thestar.com.my/business/business-n...
# 3   https://www.thestar.com.my/business/business-n...
# 4   https://www.thestar.com.my/business/business-n...
# 5   https://www.thestar.com.my/business/business-n...
# 6   https://www.thestar.com.my/business/business-n...
# 7   https://www.thestar.com.my/business/business-n...
# 8   https://www.thestar.com.my/business/business-n...
# 9   https://www.thestar.com.my/business/business-n...
# 14          https://www.thestartv.com/v/5e6207b3e1a59
# 15  https://www.thestar.com.my/business/business-n...
# 16  https://www.thestar.com.my/business/business-n...
# 17  https://www.thestar.com.my/business/business-n...
# 18  https://www.thestar.com.my/business/business-n...
# 19  https://www.thestar.com.my/business/business-n...
# 20  https://www.thestar.com.my/news/education/2020...
# 21  https://www.thestar.com.my/business/business-n...
# 22  https://www.thestar.com.my/business/business-n...
# 23  https://www.thestar.com.my/business/business-n...
# 24  https://www.thestar.com.my/business/business-n...
# 25  https://www.thestar.com.my/business/business-n...
# 26  https://www.thestar.com.my/business/business-n...
# 27  https://www.thestar.com.my/business/business-n...
# 28  https://www.thestar.com.my/business/business-n...
# 29  https://www.thestar.com.my/business/business-n...
# 30  https://www.thestar.com.my/business/business-n...
# 31  https://www.thestar.com.my/business/business-n...
# 32  https://www.thestar.com.my/news/education/2020...

# %%
import requests
from bs4 import BeautifulSoup
import time

contentDFList = []

for i in DF["Link"]:
    print("Scraping Link",i)
    response = requests.get(i)
    soup = BeautifulSoup(response.content,'html.parser')
    element_list = soup.find_all("p")
    if element_list != []:
        text_list = []
        for element in element_list:
            text_list.append(element.get_text())
        try:
            trimmingIndex = text_list.index("We're sorry, this article is unavailable at the moment. If you wish to read this article, kindly contact our Customer Service team at 1-300-88-7827. Thank you for your patience - we're bringing you a new and improved experience soon!")
        except:
            try:
                trimmingIndex = text_list.index(" ")
            except:
                contentDFList.append([i,"NA","NA","NA"])
                continue
        day = text_list[0].replace("\n","").strip().split(",")[0]
        date = text_list[0].replace("\n","").strip().split(",")[1].strip()
        content = ''.join(text_list[1:trimmingIndex])
        contentDFList.append([i,day,date,content])
    else:
        contentDFList.append([i,"NA","NA","NA"])
    time.sleep(2)
# Out:
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/chips-sector-hard-hit-by-covid-19
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/foreign-selling-extends-to-third-week
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/carnage-in-oil-markets-batter-bursa039s-oil-and-gas-stocks
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/quick-take-oil-and-gas-counters-tumble-after-oil-price-crashes
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/affin-hwang-maintains-039netural039-on-telcos-maxis-is-top-pick
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/trading-ideas-trc-synergy-acoustech-vsolar-sinotop
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/saudi-arabia-plans-big-oil-output-hike-beginning-all-out-price-war
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/vehicle-sales-expected-to-grow-9-this-year
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/datasonic-md-says-firms-ability-to-secure-govt-passport-chip-contract-based-on-merit
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/ringgit-extends-last-week039s-loss-against-the-us
# Scraping Link https://www.thestartv.com/v/5e6207b3e1a59
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/cgs-cimb-research-sees-dialog-lotte-winning-in-oil-carnage
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/reconfigured-area-could-boost-rental-income-for-klccp-stapled-group
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/putin-starts-war-on-shale-oil
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/boeings-new-ceo-regrets-blasting-predecessor-as-backlash-grows
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/zafrul-smes-deserve-all-help-during-trying-times
# Scraping Link https://www.thestar.com.my/news/education/2020/03/09/engineered-for-success?utm_medium=thestar&utm_source=secpmnewslisting&utm_campaign=20200309_HWUM_ProvostTalk
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/virus-forces-asias-super-rich-to-work-from-home
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/how-artificial-intelligence-will-change-the-construction-sector
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/aramco-slumps-below-ipo-price
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/japans-timber-boost-for-ta-ann
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/s-p-setia-set-to-achieve-higher-earnings-this-year
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/investors-look-for-buys-as-virus-fears-crush-travel-stocks
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/jpmorgan-sees-early-signs-of-stress-on-credit-and-funding
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/central-banks-search-for-answers-to-virus-impact
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/globetronics-plans-rm30mil-capex-for-first-half
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/sinotop-set-to-enter-govt-e-services-space
# Scraping Link https://www.thestar.com.my/business/business-news/2020/03/09/need-for-global-cooperation-to-save-the-day
# Scraping Link https://www.thestar.com.my/news/education/2020/03/09/engineered-for-success?utm_medium=thestar&utm_source=rosnawidget&utm_campaign=20200309_HWUM_ProvostTalk

# %%
contentDF = pd.DataFrame(contentDFList, columns = ["Link","Day","Date","Content"])
mergedDF = DF.merge(contentDF, left_on="Link", right_on="Link")
mergedDF.drop(columns=["Link"])
# Out:
#                                                 Title  \
# 0                   Chips sector hard hit by Covid-19
# 1               Foreign selling extends to third week
# 2   Carnage in oil markets batter Bursa's oil and ...
# 3   Quick take: Oil and gas counters tumble after ...
# 4   Affin Hwang maintains 'netural' on telcos, Max...
# 5   Trading ideas: TRC Synergy, Acoustech, Vsolar,...
# 6   Saudi Arabia plans big oil output hike, beginn...
# 7         Vehicle sales expected to grow 9% this year
# 8   Datasonic MD says firm’s ability to secure gov...
# 9    Ringgit extends last week's loss against the US$
# 10                       An uphill task for Muhyiddin
# 11  CGS-CIMB Research sees Dialog, Lotte winning i...
# 12  Reconfigured area could boost rental income fo...
# 13                      Putin starts war on shale oil
# 14  Boeing’s New CEO regrets blasting predecessor ...
# 15  Zafrul: SMEs deserve all help during trying times
# 16                             Engineered for success
# 17   Virus forces Asia’s super rich to work from home
# 18  How artificial intelligence will change the co...
# 19                      Aramco slumps below IPO price
# 20                    Japan’s timber boost for Ta Ann
# 21  S P Setia set to achieve higher earnings this ...
# 22  Investors look for buys as virus fears crush t...
# 23  JPMorgan sees ‘early signs’ of stress on credi...
# 24   Central banks search for answers to virus impact
# 25    Globetronics plans RM30mil capex for first half
# 26         Sinotop set to enter govt e-services space
# 27        Need for global cooperation to save the day
# 28                             Engineered for success
#
#                                   Author     Day         Date  \
# 0                                     NA  Monday  09 Mar 2020
# 1                         Leong Hung Yee  Monday  09 Mar 2020
# 2                            Joseph Chin  Monday  09 Mar 2020
# 3                                     NA  Monday  09 Mar 2020
# 4                                     NA  Monday  09 Mar 2020
# 5                                     NA  Monday  09 Mar 2020
# 6                                     NA  Monday  09 Mar 2020
# 7                                     NA  Monday  09 Mar 2020
# 8                                     NA  Monday  09 Mar 2020
# 9                                     NA  Monday  09 Mar 2020
# 10                                    NA      NA           NA
# 11                                    NA  Monday  09 Mar 2020
# 12                                    NA  Monday  09 Mar 2020
# 13                                    NA  Monday  09 Mar 2020
# 14                                    NA  Monday  09 Mar 2020
# 15                                    NA  Monday  09 Mar 2020
# 16                                    NA      NA           NA
# 17                                    NA  Monday  09 Mar 2020
# 18  Comment - By Parameswaran Sivalingam  Monday  09 Mar 2020
# 19                                    NA  Monday  09 Mar 2020
# 20                             JACK WONG  Monday  09 Mar 2020
# 21                  By EUGENE MAHALINGAM  Monday  09 Mar 2020
# 22                                    NA  Monday  09 Mar 2020
# 23                                    NA  Monday  09 Mar 2020
# 24                                    NA  Monday  09 Mar 2020
# 25                          By DAVID TAN  Monday  09 Mar 2020
# 26                        By TEE LIN SAY  Monday  09 Mar 2020
# 27     Plain Speaking - By Yap Leng Kuen  Monday  09 Mar 2020
# 28                                    NA      NA           NA
#
#                                               Content
# 0   By DAVID TANMini-Circuits Technologies In Baya...
# 1   By Leong Hung YeeInternational investors took ...
# 2   By Joseph ChinKUALA LUMPUR: The carnage in oil...
# 3   KUALA LUMPUR: Oil and gas counters on Bursa Ma...
# 4
# 5   KUALA LUMPUR: JF Apex Research expects TRC SYN...
# 6   DUBAI: Saudi Arabia plans to increase oil outp...
# 7   By EUGENE MAHALINGAMAnalysts sceptical based o...
# 8   By INTAN FARHANA ZAINULDatasonic MD Chew Ben B...
# 9   KUALA LUMPUR: The ringgit extended last week's...
# 10                                                 NA
# 11  The research house said Dialog can potentially...
# 12
# 13  Putin’s visit: Putin touring the stock company...
# 14  Boeing Dave CalhounCHICAGO: Boeing Co chief ex...
# 15  “As the backbone of the nation’s economy, the ...
# 16                                                 NA
# 17  HONG KONG: Asia’s super rich suddenly have lot...
# 18  By Parameswaran SivalingamArtifical intelligen...
# 19  DUBAI: Saudi Aramco dropped below the IPO leve...
# 20  By JACK WONGKUCHING: TA ANN HOLDINGS BHD expec...
# 21  By EUGENE MAHALINGAMPETALING JAYA: S P Setia B...
# 22  \n\n\n\nVirus spreads: A person wearing a face...
# 23  SINGAPORE: The fallout from the global spread ...
# 24  FILE PHOTO: European Central Bank (ECB) headqu...
# 25  By DAVID TANGlobetronics Technology Bhd plans ...
# 26  By TEE LIN SAYFor now, the MyPal portal is 80%...
# 27  By Yap Leng KuenLee Heng Guie SERCTOUGH as it ...
# 28                                                 NA

# %% [markdown]
# So far this is a good start. Now lets combine each component into a python class that could be executed daily.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

class theStarBusinessScraper():
    def __init__(self):
        self.url = "www.thestar.com.my/business"
        self.chromeOptions = Options()
        self.chromeOptions.add_argument("--incognito")
        
    def startBrowser(self):
        self.browser = webdriver.Chrome(chrome_options = self.chromeOptions)
        self.browser.get(url)
        items = self.browser.find_elements_by_xpath('//h2/a[@href]')
        self.browser.close()
        return items
    
    def scrapeMainPage(self, items):
        DF_list = []
        for item in items:
            DF_list.append([item.get_attribute('data-content-title'), item.get_attribute('data-content-author'), item.get_attribute('href')])
        DF = pd.DataFrame(DF_list, columns = ["Title", "Author", "Link"])
        DF = DF.applymap(str)
        DF = DF[DF["Title"] != "None"]
        return DF
    
    def scrapeIndividualPage(self):
        
        
        
if __name__ == "__main__":
    scraper = theStarBusinessScraper()
    mainPage = scraper.startBrowser()
    DF = scrapeMainPage(mainPage)
